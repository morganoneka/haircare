# %% [markdown]
# # Amazon Product Scraping

# %%
import requests
from bs4 import BeautifulSoup
import os
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.common.exceptions import NoSuchElementException
import math
import time
import pandas as pd

# %%
df = pd.read_excel("../productpages.xlsx")

# %%
df
# Out:
#                      Brand                         Line  \
# 0        Not Your Mother's                     Naturals
# 1         Carol's Daughter          Curly Hair Products
# 2         Carol's Daughter    Shampoos and Conditioners
# 3         Carol's Daughter                    Leave-Ins
# 4         Carol's Daughter         Masks and Treatments
# 5         Carol's Daughter                      Styling
# 6             SheaMoisture    Jamaican Black Castor Oil
# 7             SheaMoisture         Coconut and Hibiscus
# 8             SheaMoisture      100% Virgin Coconut Oil
# 9             SheaMoisture      Manuka Honey and Yogurt
# 10            SheaMoisture  Manuka Honey and Mafura Oil
# 11                   Curls              Blueberry Bliss
# 12                  Moptop                      Shampoo
# 13                  Moptop                  Conditioner
# 14                  Moptop                          Gel
# 15             Cake Beauty                         Hair
# 16                Giovanni          Curly Girl Products
# 17                TRESemme            Curly & Wavy Hair
# 18                Pacifica                         Hair
# 19  Uncle Funky's Daughter                    Cleansers
# 20  Uncle Funky's Daughter                 Conditioners
# 21  Uncle Funky's Daughter                 Moisturizers
# 22  Uncle Funky's Daughter                Curl Definers
# 23           Maui Moisture                 All Products
#
#                                                   URL
# 0   https://www.amazon.com/stores/page/AD6500C9-1C...
# 1   https://www.amazon.com/stores/page/A5D6BF5C-26...
# 2   https://www.amazon.com/stores/page/FB3658B5-14...
# 3   https://www.amazon.com/stores/page/0E98909E-6E...
# 4   https://www.amazon.com/stores/page/DE3D32F1-89...
# 5   https://www.amazon.com/stores/page/FAFBE68C-47...
# 6   https://www.amazon.com/stores/page/A03541FA-F1...
# 7   https://www.amazon.com/stores/page/6013C3E4-60...
# 8   https://www.amazon.com/stores/page/7D202725-D6...
# 9   https://www.amazon.com/stores/page/FDA558AB-CB...
# 10  https://www.amazon.com/stores/page/35B9F3E1-58...
# 11  https://www.amazon.com/stores/page/BC4E2BD8-C4...
# 12  https://www.amazon.com/stores/page/C7839886-31...
# 13  https://www.amazon.com/stores/page/5B82851D-8A...
# 14  https://www.amazon.com/stores/page/E33C4213-A3...
# 15  https://www.amazon.com/stores/page/D3C56514-6F...
# 16  https://www.amazon.com/stores/page/BFA41C66-2A...
# 17  https://www.amazon.com/stores/page/0348F487-25...
# 18  https://www.amazon.com/stores/page/F1FD0DEA-EE...
# 19  https://www.amazon.com/stores/page/92C11C4D-E1...
# 20  https://www.amazon.com/stores/page/A3E00274-E1...
# 21  https://www.amazon.com/stores/page/CCAE06CF-E9...
# 22  https://www.amazon.com/stores/page/6D5C00F9-C3...
# 23  https://www.amazon.com/stores/page/3E2D6F31-1B...

# %%
driver = webdriver.Firefox(executable_path=r'/Users/morganoneka/Documents/PersonalProjects/geckodriver')

# %%
def get_item_list(brand_page):
    # pull up brand page
    driver.get(brand_page)
    time.sleep(5)
    
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    # get list of all items
    items = soup.find_all("div", class_="columns")[0].find_all("li")
    
#     return(["https://www.amazon.com" + item.find_all("a")[0].get("href") for item in items])
    return([get_item_url_from_listing(item) for item in items])

def get_item_url_from_listing(listing):
    try:
        return ("https://www.amazon.com" + listing.find_all("a")[0].get("href") )
    except:
        return ""

def get_review_url(product_url):
    sp = product_url.split("/")
    return('/'.join(sp[:4]) + "/product-reviews/" + sp[-1].split("?")[0] + "/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews")

# url = page for the individual project
def get_product_reviews(url):
    # navigate to product home page
    driver.get(url)

    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    # get product title
    product = soup.find(id="productTitle").text.strip()

    # determine url for reviews and navigate
    review_url = get_review_url(item_page)
    driver.get(review_url)
    time.sleep(5)

    # get data from review page
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    # identify how many reviews with text there are
    review_info = soup.find_all("div", class_="a-row a-spacing-base a-size-base")[0].text.split()
    num_reviews = int([x for x in review_info if x.strip().isnumeric()][-1])

    # iterate over all reviews
    revs = []
    for pg in range(math.ceil(num_reviews/10)):
        # get page - either base review url, or with page number added
        if pg > 0:
            driver.get(review_url + "&pageNumber=" + str(pg+1))
            # wait for page to load
            time.sleep(5)

            # get html
            html = driver.page_source
            soup = BeautifulSoup(html, "html.parser")

        # get list of reviews
        page_reviews = soup.find("div", id="cm_cr-review_list").find_all("div", class_="review")

        # get info from reviews
        for single_review in page_reviews:
            rating = single_review.find_all("a", class_="a-link-normal")[0].text
            title = single_review.find_all("a", class_="a-link-normal")[1].text.strip()
            review = single_review.find("span", class_="review-text-content").text.strip()
            revs.append([product,rating,title,review])


    return(pd.DataFrame(revs, columns=['Product', 'Rating', 'Title', 'Review']))

# %%
for index, row in df.iterrows():
    # get page for brand's line
    brand_page = row.URL
    
    brand = row.Brand
    line = row.Line
    
    if os.path.exists("../output/amazon/" + brand + "_" + line + ".csv"):
        continue
        
    print (brand + "\t" + line)
    
    
    # get list of urls for each item
    items = [x for x in get_item_list(brand_page) if x != '']
    
    review_list = []
    
    
    for item_page in items:
        print(item_page)
        
        try:
            item_reviews = get_product_reviews(item_page)
            review_list.append(item_reviews)
        except:
            print("issue")
        
    pd.concat(review_list).to_csv("../output/amazon/" + brand + "_" + line + ".csv")
# Out:
# Giovanni	Curly Girl Products
# https://www.amazon.com/GIOVANNI-COSMETICS-Leave-Conditioner-Weightless/dp/B001ET78BU?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-Eco-Chic-Natural-Styling/dp/B001ET78CO?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-COSMETICS-Natural-Styling-Air-Turbo/dp/B001ET789M?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-Chic-Frizz-Gone-2-75/dp/B001ET78CY?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Giovanni-conditioner-weightless-18615-Grapefruit/dp/B084445YKB?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-Smooth-Silk-Shampoo-Pack/dp/B001G7PLDW?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Giovanni-Conditioner-Smooth-Damaged-Bottle/dp/B00066D2JE?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-COSMETICS-Conditioner-Moisture-Damaged/dp/B001ET7892?ref_=ast_sto_dp
# https://www.amazon.com/Giovanni-Moisturizing-Conditioner-Detangles-Sulfate/dp/B07NP3X7PV?ref_=ast_sto_dp
# https://www.amazon.com/GIOVANNI-Smooth-Conditioner-Moisture-Damaged/dp/B00B620YU2?ref_=ast_sto_dp
# https://www.amazon.com/Giovanni-Cosmetics-Conditioner-Silk-Smooth/dp/B000WR4444?ref_=ast_sto_dp
ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Beauty-Salty-Waves-Beach/dp/B07D8LH7Y7?ref_=ast_sto_dp
# https://www.amazon.com/Pacifica-Beauty-Salty-Waves-Texture/dp/B0792KVB1X?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Coconut-Moisturizing-Shampoo-Damaged/dp/B098RCRRGQ?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-water-sleek-shiny-shampoo/dp/B082G22JGN?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Beauty-Coconut-Healing-Conditioner/dp/B01MFXKLKI?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Coconut-milk-detangle-elixir/dp/B084F3K4MJ?ref_=ast_sto_dp
# https://www.amazon.com/Pacifica-Rosemary-Invigorating-Shampoo-Conditioner/dp/B098RCTB95?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Rosemary-Purify-Invigorating-Shampoo/dp/B084F31GNK?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Rosemary-purify-invigorating-conditioner/dp/B084F2SVN7?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Rosemary-Exfoliates-Product-Buildup/dp/B09G1421DV?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Scalp-love-rosemary-serum/dp/B084F2VFXQ?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Rosemary-detox-scalp-scrub/dp/B0849SYH2N?ref_=ast_sto_dp&th=1&psc=1
# https://www.amazon.com/Pacifica-Sunshine-Shampoo-Conditioner-Neutralizing/dp/B09C111FLH?ref_=ast_sto_dp
# https://www.amazon.com/Pacifica-Shampoo-Conditioner-Vanilla-Hydration/dp/B09K1QNKLM?ref_=ast_sto_dp
# Uncle Funky's Daughter	Cleansers
# https://www.amazon.com/Uncle-Funkys-Daughter-Squeaky-Cleansing/dp/B00P8A97GK?ref_=ast_sto_dp
# https://www.amazon.com/Uncle-Funkys-Daughter-Moisturizing-Shampoo/dp/B00P8CXQOW?ref_=ast_sto_dp
# https://www.amazon.com/Bye-Bye-Buildup-Cleansing-Conditioner-Co-wash/dp/B07CMD5QKJ?ref_=ast_sto_dp
# https://www.amazon.com/Uncle-Funkys-Daughter-Defunk-Refresher/dp/B00P8CEG3W?ref_=ast_sto_dp
# https://www.amazon.com/Uncle-Funkys-Daughter-Squeaky-32oz/dp/B087KWZK9X?ref_=ast_sto_dp
# https://www.amazon.com/Maximum-Thermal-Protection-Purifying-Cleanser/dp/B096YHP2DZ?ref_=ast_sto_dp
# Uncle Funky's Daughter	Conditioners
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-eab19018a6df> in <module>
#      13
#      14     # get list of urls for each item
# ---> 15     items = [x for x in get_item_list(brand_page) if x != '']
#      16
#      17     review_list = []
#
# <ipython-input-74-ce261c62b08b> in get_item_list(brand_page)
#       8
#       9     # get list of all items
# ---> 10     items = soup.find_all("div", class_="columns")[0].find_all("li")
#      11
#      12 #     return(["https://www.amazon.com" + item.find_all("a")[0].get("href") for item in items])
#
# IndexError: list index out of range

# %%
row = df.iloc[1]

# %%
brand_page = row.URL
brand = row.Brand
line = row.Line

# %%
get_item_list(brand_page)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-f078e2247c48> in <module>
# ----> 1 get_item_list(brand_page)
#
# <ipython-input-48-f7113b60c56f> in get_item_list(brand_page)
#       8
#       9     # get list of all items
# ---> 10     items = soup.find_all("div", class_="columns")[0].find_all("li")
#      11
#      12 #     return(["https://www.amazon.com" + item.find_all("a")[0].get("href") for item in items])
#
# IndexError: list index out of range

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# %%
items = soup.find_all("div", class_="columns")

# %%
len(items)
# Out:
# 1

# %%
items = soup.find_all("div", class_="columns")[0].find_all("li")

# %%
len(items)
# Out:
# 8
